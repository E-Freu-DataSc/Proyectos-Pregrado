# %%
from Plot_Maps.Creacion_datos_coordenadas import añadir_coordenadas
from Plot_Maps.Creacion_mapas import create_map_folium, create_map_dash
from Preprocess_data.Class.DataProcessor import DataProcessor


# Define la ruta de tus datos
data_path = r"C:\Users\Usuario\OneDrive - udd.cl\Datos adjuntos\Bootcamp ciencia de datos\Modulo 7\Proyecto_7_Organizacion_Presentación_Esteban_Freudenberg_UDD\Github_Proyecto_7\Proyectos-Pregrado\Datasets\raw\Oscars-demographics-DFE.csv"

# Llama al método preprocess_data() para procesar los datos

# %%
processor = DataProcessor(data_path)
processor.preprocess_data()

# %%
Oscar_con_coordenadas = añadir_coordenadas(processor.data)

# %%
create_map_folium(r"C:\Users\Usuario\OneDrive - udd.cl\Datos adjuntos\Bootcamp ciencia de datos\Modulo 7\Proyecto_7_Organizacion_Presentación_Esteban_Freudenberg_UDD\Github_Proyecto_7\Proyectos-Pregrado\Datasets\processed\Oscars_con_coordenadas.csv")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_56df43aadcea427f206c577f8cb2d9a4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_56df43aadcea427f206c577f8cb2d9a4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_56df43aadcea427f206c577f8cb2d9a4 = L.map(
#                 &quot;map_56df43aadcea427f206c577f8cb2d9a4&quot;,
#                 {
#                     center: [34.0928092, -118.3286614],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_44990b9cb46bf884bacb40feccdc776d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_56df43aadcea427f206c577f8cb2d9a4);
#
#
#             var marker_8568bf6450fd0572e96f37890a620bf2 = L.marker(
#                 [47.010452, 28.86381],
#                 {}
#             ).addTo(map_56df43aadcea427f206c577f8cb2d9a4);
#
#
#         var popup_864b8c1c9b1db10f6eac1ab45fcaec3a = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_9fbf942280439cb12efc0498422c553a = $(`&lt;div id=&quot;html_9fbf942280439cb12efc0498422c553a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lugar nacimiento: Chisinau_Moldova&lt;br&gt;Premiado: Lewis_Milestone&lt;br&gt;Año premiación: 1927&lt;/div&gt;`)[0];
#                 popup_864b8c1c9b1db10f6eac1ab45fcaec3a.setContent(html_9fbf942280439cb12efc0498422c553a);
#
#
#
#         marker_8568bf6450fd0572e96f37890a620bf2.bindPopup(popup_864b8c1c9b1db10f6eac1ab45fcaec3a)
#         ;
#
#
#
#
#             var marker_c32c1174dea9369ec974fe24f30422e7 = L.marker(
#                 [55.864237, -4.251806],
#                 {}
#             ).addTo(map_56df43aadcea427f206c577f8cb2d9a4);
#
#
#         var popup_a6f7c59b7b0ff46fb6208a3a65b18831 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_e6d3cff7e62d7593c9554d8d72768476 = $(`&lt;div id=&quot;html_e6d3cff7e62d7593c9554d8d72768476&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lugar nacimiento: Glasgow_Scotland&lt;br&gt;Premiado: Frank_Lloyd&lt;br&gt;Año premiación: 1930&lt;/div&gt;`)[0];
#                 popup_a6f7c59b7b0ff46fb6208a3a65b18831.setContent(html_e6d3cff7e62d7593c9554d8d72768476);
#
#
#
#         marker_c32c1174dea9369ec974fe24f30422e7.bindPopup(popup_a6f7c59b7b0ff46fb6208a3a65b18831)
#         ;
#
#
#
#
#             var marker_9b9e6213da46f1964fe371afe621e735 = L.marker(
#                 [47.010452, 28.86381],
#                 {}
#             ).addTo(map_56df43aadcea427f206c577f8cb2d9a4);
#
#
#         var popup_babcf0000cdbea789ec3c1c272ba9842 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_29503014e7f27ac91575ce9e353bf95c = $(`&lt;div id=&quot;html_29503014e7f27ac91575ce9e353bf95c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lugar nacimiento: Chisinau_Moldova&lt;br&gt;Premiado: Lewis_Milestone&lt;br&gt;Año premiación: 1931&lt;/div&gt;`)[0];
#                 popup_babcf0000cdbea789ec3c1c272ba9842.setContent(html_29503014e7f27ac91575ce9e353bf95c);
#
#
#
#         marker_9b9e6213da46f1964fe371afe621e735.bindPopup(popup_babcf0000cdbea789ec3c1c272ba9842)
#         ;
#
#
#
#
#             var marker_051579ac142963ba78772f54c4982b0e = L.marker(
#                 [41.878113, -87.629799],
#                 {}
#             ).addTo(map_56df43aadcea427f206c577f8cb2d9a4);
#
#
#         var popup_66d2c93204a485d8f87d40c020c4193d = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_584a9720c1874b4747da4c6b1298ec45 = $(`&lt;div id=&quot;html_584a9720c1874b4747da4c6b1298ec45&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lugar nacimiento: Chicago_Il&lt;br&gt;Premiado: Norman_Taurog&lt;br&gt;Año premiación: 1932&lt;/div&gt;`)[0];
#                 popup_66d2c93204a485d8f87d40c020c4193d.setContent(html_584a9720c1874b4747da4c6b1298ec45);
#
#
#
#         marker_051579ac142963ba78772f54c4982b0e.bindPopup(popup_66d2c93204a485d8f87d40c020c4193d)
#         ;
#
#
#
#
#             var marker_02a5dedcea6e9fd02616c47f368be2fd = L.marker(
#                 [40.760779, -111.891047],
#                 {}
#             ).addTo(map_56df43aadcea427f206c577f8cb2d9a4);
#
#
#         var popup_59fc5ad873c7f73fe47869de84a6dc9a = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_267d0a58d63d549cc12c68835105a790 = $(`&lt;div id=&quot;html_267d0a58d63d549cc12c68835105a790&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lugar nacimiento: Salt_Lake_City_Ut&lt;br&gt;Premiado: Frank_Borzage&lt;br&gt;Año premiación: 1933&lt;/div&gt;`)[0];
#                 popup_59f
