# %%
conda activate Entorno_Proyecto_7
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
from Plot_Maps.Creacion_datos_coordenadas import añadir_coordenadas
from Plot_Maps.Creacion_mapas import create_map_folium, create_map_dash
from Preprocess_data.Class.DataProcessor import DataProcessor


# Define la ruta de tus datos
data_path = r"C:\Users\Usuario\OneDrive - udd.cl\Datos adjuntos\Bootcamp ciencia de datos\Modulo 7\Proyecto_7_Organizacion_Presentación_Esteban_Freudenberg_UDD\Github_Proyecto_7\Proyectos-Pregrado\Datasets\raw\Oscars-demographics-DFE.csv"
# Out:
# c:\Users\Usuario\OneDrive - udd.cl\Datos adjuntos\Bootcamp ciencia de datos\Modulo 7\Proyecto_7_Organizacion_Presentación_Esteban_Freudenberg_UDD\Github_Proyecto_7\Proyectos-Pregrado\Preprocess_data\Class\DataProcessor.py:14: UserWarning:
# The dash_core_components package is deprecated. Please replace
# `import dash_core_components as dcc` with `from dash import dcc`
#   import dash_core_components as dcc
# c:\Users\Usuario\OneDrive - udd.cl\Datos adjuntos\Bootcamp ciencia de datos\Modulo 7\Proyecto_7_Organizacion_Presentación_Esteban_Freudenberg_UDD\Github_Proyecto_7\Proyectos-Pregrado\Preprocess_data\Class\DataProcessor.py:15: UserWarning:
# The dash_html_components package is deprecated. Please replace
# `import dash_html_components as html` with `from dash import html`
#   import dash_html_components as html

# %%
processor = DataProcessor(data_path)
processor.preprocess_data()

# %%
Oscar_con_coordenadas = añadir_coordenadas(processor.data)

# %%
create_map_folium(r"C:\Users\Usuario\OneDrive - udd.cl\Datos adjuntos\Bootcamp ciencia de datos\Modulo 7\Proyecto_7_Organizacion_Presentación_Esteban_Freudenberg_UDD\Github_Proyecto_7\Proyectos-Pregrado\Datasets\processed\Oscars_con_coordenadas.csv")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_70a4476800385132a7331f1410311ba0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_70a4476800385132a7331f1410311ba0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_70a4476800385132a7331f1410311ba0 = L.map(
#                 &quot;map_70a4476800385132a7331f1410311ba0&quot;,
#                 {
#                     center: [34.0928092, -118.3286614],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_102b2f51850a8d7c9d7a28f9b79f3bf1 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_70a4476800385132a7331f1410311ba0);
#
#
#             var marker_cfe100b13d91dd7234bfcaad3cd40edd = L.marker(
#                 [47.010452, 28.86381],
#                 {}
#             ).addTo(map_70a4476800385132a7331f1410311ba0);
#
#
#         var popup_d1f79bf66bcaa6ac921b0ea9655a1188 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_58b1ed8a16989fe91759327adb68d50a = $(`&lt;div id=&quot;html_58b1ed8a16989fe91759327adb68d50a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lugar nacimiento: Chisinau_Moldova&lt;br&gt;Premiado: Lewis_Milestone&lt;br&gt;Año premiación: 1927&lt;/div&gt;`)[0];
#                 popup_d1f79bf66bcaa6ac921b0ea9655a1188.setContent(html_58b1ed8a16989fe91759327adb68d50a);
#
#
#
#         marker_cfe100b13d91dd7234bfcaad3cd40edd.bindPopup(popup_d1f79bf66bcaa6ac921b0ea9655a1188)
#         ;
#
#
#
#
#             var marker_43ff5456ac6e62e9d48501da83ddb0db = L.marker(
#                 [55.864237, -4.251806],
#                 {}
#             ).addTo(map_70a4476800385132a7331f1410311ba0);
#
#
#         var popup_632092d0dfd207775d9a4830cdfa7a45 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_5e7344a6e452c573f9ac071d512b62a5 = $(`&lt;div id=&quot;html_5e7344a6e452c573f9ac071d512b62a5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lugar nacimiento: Glasgow_Scotland&lt;br&gt;Premiado: Frank_Lloyd&lt;br&gt;Año premiación: 1930&lt;/div&gt;`)[0];
#                 popup_632092d0dfd207775d9a4830cdfa7a45.setContent(html_5e7344a6e452c573f9ac071d512b62a5);
#
#
#
#         marker_43ff5456ac6e62e9d48501da83ddb0db.bindPopup(popup_632092d0dfd207775d9a4830cdfa7a45)
#         ;
#
#
#
#
#             var marker_c087c6a9bd8d210d8a21710bdb566afd = L.marker(
#                 [47.010452, 28.86381],
#                 {}
#             ).addTo(map_70a4476800385132a7331f1410311ba0);
#
#
#         var popup_03893d88e5f24e9724440959ddf9bfa6 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_954a55aaa99ec00a192c1cdfe3f5518f = $(`&lt;div id=&quot;html_954a55aaa99ec00a192c1cdfe3f5518f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lugar nacimiento: Chisinau_Moldova&lt;br&gt;Premiado: Lewis_Milestone&lt;br&gt;Año premiación: 1931&lt;/div&gt;`)[0];
#                 popup_03893d88e5f24e9724440959ddf9bfa6.setContent(html_954a55aaa99ec00a192c1cdfe3f5518f);
#
#
#
#         marker_c087c6a9bd8d210d8a21710bdb566afd.bindPopup(popup_03893d88e5f24e9724440959ddf9bfa6)
#         ;
#
#
#
#
#             var marker_958ab1f4f2c167bccf8ca2343e8417e2 = L.marker(
#                 [41.878113, -87.629799],
#                 {}
#             ).addTo(map_70a4476800385132a7331f1410311ba0);
#
#
#         var popup_41b7ebd5f70b4b35c07b1228b3679a49 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_f71af2a1f2aea423841a3bbba6926f0c = $(`&lt;div id=&quot;html_f71af2a1f2aea423841a3bbba6926f0c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lugar nacimiento: Chicago_Il&lt;br&gt;Premiado: Norman_Taurog&lt;br&gt;Año premiación: 1932&lt;/div&gt;`)[0];
#                 popup_41b7ebd5f70b4b35c07b1228b3679a49.setContent(html_f71af2a1f2aea423841a3bbba6926f0c);
#
#
#
#         marker_958ab1f4f2c167bccf8ca2343e8417e2.bindPopup(popup_41b7ebd5f70b4b35c07b1228b3679a49)
#         ;
#
#
#
#
#             var marker_2dd47267534c935c93b024bca1fbd009 = L.marker(
#                 [40.760779, -111.891047],
#                 {}
#             ).addTo(map_70a4476800385132a7331f1410311ba0);
#
#
#         var popup_eaacf5c564902ca70bab6ea62dc59de8 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_9162666faa0835d92ef3608a976c27ac = $(`&lt;div id=&quot;html_9162666faa0835d92ef3608a976c27ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lugar nacimiento: Salt_Lake_City_Ut&lt;br&gt;Premiado: Frank_Borzage&lt;br&gt;Año premiación: 1933&lt;/div&gt;`)[0];
#                 popup_eaa
