# %%
conda activate Entorno_Proyecto_7
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
pip freeze > requirements.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Demographics of Academy Awards (Oscars) Winners
#
# ### Introducción
# Este dataset contiene los ganadores de los Oscars desde 1928 hasta el año 2014.
#
# Se concideradon las siguientes categorias:
# - Mejor director
# - Mejor actor
# - Mejor actor de reparto
# - Mejor actriz
# - Mejor actriz de reparto
#
# ### Descripcion del dataframe
#
# Es un dataframe que contiene 441 filas y 27 columnas
# Valores Faltantes: Hay un total de 2,373 valores faltantes en todo el dataset.
# Categorical Columns: 16
# Numerical Columns: 11
#
# #### Columnas Categóricas:
#
# - _unit_state: Estado de la unidad.
# - birthplace: Lugar de nacimiento del galardonado.
# - date_of_birth: Fecha de nacimiento del galardonado.
# - race_ethnicity: Raza o etnicidad del galardonado.
# - religion: Religión del galardonado.
# - sexual_orientation: Orientación sexual del galardonado.
# - award: Categoría del premio ganado.
# - biourl: URL de la biografía.
# - birthplace_gold:
# - date_of_birth_gold:
# - movie: Película por la que se otorgó el premio.
# - person: Nombre del galardonado.
# - race_ethnicity_gold:
# - religion_gold:
# - sexual_orientation_gold:
# - _golden:
#
# #### Columnas Numéricas
#
# - **_unit_id**: Identificador.
# - **_trusted_judgments**:
# - **birthplace:confidence**: Puntuación de confianza para la información del lugar de nacimiento.
# - **date_of_birth:confidence**: Puntuación de confianza para la información de la fecha de nacimiento.
# - **race_ethnicity::confidence**: Puntuación de confianza para la información sobre raza o etnicidad.
# - **religion::confidence**: Puntuación de confianza para la información sobre religión.
# - **sexual_orientation::confidence**: Puntuación de confianza para la información sobre orientación sexual.
# - **year_of_award**: Año en que se otorgó el premio.
# - **year_of_award_gold**:
# - **_last_judgment_at**: Fecha del último juicio.
#
# ### Primera apreciación
#
# Es un dataset simple, de datos demograficos, el cual contiene columnas irrelevantes o que no se entiende su utilidad(No hay información en el repositorio). Debido a la naturaleza de los datos parece no ser posible crear un modelo predictivo de machine learning, un analisis posterior me ayudara a aclarar esa posibilidal. El camino, en mi opinion, es realizar un mapa, analisis estadisticos para describir los datos con graficos y mostrar tendencias.
# .

# %%
import pandas as pd
import numpy as np


file_path = r"C:\Users\Usuario\OneDrive - udd.cl\Datos adjuntos\Bootcamp ciencia de datos\Modulo 7\Proyecto_7_Organizacion_Presentación_Esteban_Freudenberg_UDD\Github_Proyecto_7\Proyectos-Pregrado\Data_used\raw\Oscars-demographics-DFE.csv"
Oscars_df = pd.read_csv(file_path, encoding='ISO-8859-1')

Oscar_info = Oscars_df.info()
Oscar_description = Oscars_df.describe(include='all')
Oscar_missing_values = Oscars_df.isnull().sum()
Oscar_total_missing = Oscar_missing_values.sum()

categorical_columns = Oscars_df.select_dtypes(include=['object']).columns.tolist()
numerical_columns = Oscars_df.select_dtypes(exclude=['object']).columns.tolist()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 441 entries, 0 to 440
# Data columns (total 27 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   _unit_id                       441 non-null    int64
#  1   _golden                        441 non-null    bool
#  2   _unit_state                    441 non-null    object
#  3   _trusted_judgments             441 non-null    int64
#  4   _last_judgment_at              416 non-null    object
#  5   birthplace                     441 non-null    object
#  6   birthplace:confidence          441 non-null    float64
#  7   date_of_birth                  441 non-null    object
#  8   date_of_birth:confidence       441 non-null    float64
#  9   race_ethnicity                 441 non-null    object
#  10  race_ethnicity:confidence      441 non-null    float64
#  11  religion                       441 non-null    object
# ...

# %%
print(len(categorical_columns))
print(len(numerical_columns))
# Out:
# 16
# 11

# %%
# Calculate the percentage of completeness for each column
completeness_percentage = (1 - (Oscar_missing_values / Oscars_df.shape[0])) * 100

Completitud_oscar = pd.DataFrame({
    'Valores Faltantes': Oscar_missing_values,
    'Porcentaje de Completitud (%)': completeness_percentage
})
Completitud_oscar
# Out:
#                                Valores Faltantes  \
# _unit_id                                       0
# _golden                                        0
# _unit_state                                    0
# _trusted_judgments                             0
# _last_judgment_at                             25
# birthplace                                     0
# birthplace:confidence                          0
# date_of_birth                                  0
# date_of_birth:confidence                       0
# race_ethnicity                                 0
# race_ethnicity:confidence                      0
# religion                                       0
# religion:confidence                            0
# sexual_orientation                             0
# sexual_orientation:confidence                  0
# year_of_award                                  0
# year_of_award:confidence                       0
# award                                          0
# ...

# %%
import pandas as pd

# Establecer la opción de visualización para mostrar todos los elementos en una serie
pd.set_option('display.max_seq_items', None)

unique_values = {column: Oscars_df[column].unique() for column in Oscars_df.columns}

# Imprimir los valores únicos
for column, values in unique_values.items():
    print(f"Valores únicos en la columna '{column}':")
    print(values)
    print("\n")
# Out:
# Valores únicos en la columna '_unit_id':
# [670454353 670454354 670454355 670454356 670454357 670454358 670454359
#  670454360 670454361 670454362 670454363 670454364 670454365 670454366
#  670454367 670454368 670454369 670454370 670454371 670454372 670454373
#  670454374 670454375 670454376 670454377 670454378 670454379 670454380
#  670454381 670454382 670454383 670454384 670454385 670454386 670454387
#  670454388 670454389 670454390 670454391 670454392 670454393 670454394
#  670454395 670454396 670454397 670454398 670454399 670454400 670454401
#  670454402 670454403 670454404 670454405 670454406 670454407 670454408
#  670454409 670454410 670454411 670454412 670454413 670454414 670454415
#  670454416 670454417 670454418 670454419 670454420 670454421 670454422
#  670454423 670454424 670454425 670454426 670454427 670454428 670454429
#  670454430 670454431 670454432 670454433 670454434 670454435 670454436
#  670454437 670454438 670454439 670454440 670454441 670454442 670454443
# ...

# %% [markdown]
# ## Eliminación de columnas no relevantes

# %%
Oscars_df.drop(["_unit_id", "_last_judgment_at", "birthplace:confidence", "date_of_birth:confidence", "race_ethnicity:confidence", "religion:confidence", "sexual_orientation:confidence", "year_of_award:confidence"], inplace=True, axis=1)

# %% [markdown]
# ## Eliminacion signos de puntuación y agregar "_" en los espacios entre los nombres

# %%
import pandas as pd
import re
import numpy as np

def limpiar_valor(valor):
    if isinstance(valor, str):  # Check if valor is a string
        # Eliminar signos de puntuación
        valor_sin_puntuacion = re.sub(r'[^\w\s]', '', valor)
        # Reemplazar espacios con guiones bajos
        valor_limpio = valor_sin_puntuacion.replace(' ', '_')
        return valor_limpio
    else:
        return valor

columnas_a_limpiar = ['birthplace', 'race_ethnicity', 'religion', 'birthplace_gold', 'date_of_birth_gold', 'movie', 'person', 'race_ethnicity_gold', 'religion_gold', 'sexual_orientation_gold',"award"]
for columna in columnas_a_limpiar:
    Oscars_df[columna] = Oscars_df[columna].apply(limpiar_valor)

# %% [markdown]
# ### Tranformar year_of_award_gold a string, eliminar puntos finales y rellena valores faltantes con pd.NA(Uniformidad de los nulos), y luego convierte a dato numerico.

# %%
Oscars_df['year_of_award_gold'] = Oscars_df['year_of_award_gold'].astype(str).str.replace(r'\.$', '', regex=True).fillna(pd.NA)
Oscars_df['year_of_award_gold'] = Oscars_df['year_of_award_gold'].astype(float).astype('Int64').fillna(pd.NA)

# %% [markdown]
# ## Remplazo a mano de valores desde la pagina encontrada en la columna biourl

# %%
Oscars_df.loc[Oscars_df['person'] == 'Michael_Cimino', ['date_of_birth_gold', 'date_of_birth']] = '3-Feb-1939'
Oscars_df.loc[Oscars_df['person'] == 'Danny_Boyle', ['date_of_birth_gold', 'date_of_birth']] = "20-Oct-1956"
Oscars_df.loc[Oscars_df['person'] == 'Van_Heflin', ['date_of_birth_gold', 'date_of_birth']] = "13-Dec-1910"
Oscars_df.loc[Oscars_df['person'] == 'Jason_Robards', ['date_of_birth_gold', 'date_of_birth']] = "26-Jul-1922"
Oscars_df.loc[Oscars_df['person'] == 'James_Coburn', ['date_of_birth_gold', 'date_of_birth']] = "31-Aug-1928"
Oscars_df.loc[Oscars_df['person'] == 'Elizabeth_Taylor', ['date_of_birth_gold', 'date_of_birth']] = "27-Feb-1932"
Oscars_df.loc[Oscars_df['person'] == 'Maggie_Smith', ['date_of_birth_gold', 'date_of_birth']] = "28-Dec-1934"
Oscars_df.loc[Oscars_df['person'] == 'Faye_Dunaway', ['date_of_birth_gold', 'date_of_birth']] = "14-Jan-1941"
Oscars_df.loc[Oscars_df['person'] == 'Gwyneth_Paltrow', ['date_of_birth_gold', 'date_of_birth']] = "27-Sep-1972"
Oscars_df.loc[Oscars_df['person'] == 'Hilary_Swank', ['date_of_birth_gold', 'date_of_birth']] = "30-Jul-1974"
Oscars_df.loc[Oscars_df['person'] == 'Mary_Astor', ['date_of_birth_gold', 'date_of_birth']] = "3-May-1906"
Oscars_df.loc[Oscars_df['person'] == 'Angelina_Jolie', ['date_of_birth_gold', 'date_of_birth']] = "4-Jun-1975"
Oscars_df.loc[Oscars_df['person'] == 'Marcia_Gay_Harden', ['date_of_birth_gold', 'date_of_birth']] = "14-Aug-1959"
Oscars_df.loc[Oscars_df['person'] == "Rachel_Weisz", ['date_of_birth_gold', 'date_of_birth']] = "7-Mar-1971"
Oscars_df.loc[Oscars_df['person'] == "Hilary_Swank", ['date_of_birth_gold', 'date_of_birth']] = "30-Jul-1974"

# %% [markdown]
# ## El siguiente proceso garantiza que los datos sean actualizados entre las columnas originales y sus respectivas columnas con el sufijo _gold, asi remplazando datos que faltan. Además, maneja los valores nulos al evitar copiarlos entre las columnas.

# %%
mask = (Oscars_df["_golden"] == False)  #Tambien lo realice con True

Oscars_df.loc[mask & Oscars_df["date_of_birth"].notnull(), "date_of_birth_gold"] = Oscars_df.loc[mask & Oscars_df["date_of_birth"].notnull(), "date_of_birth"]
Oscars_df.loc[mask & Oscars_df["date_of_birth_gold"].notnull(), "date_of_birth"] = Oscars_df.loc[mask & Oscars_df["date_of_birth_gold"].notnull(), "date_of_birth_gold"]

Oscars_df.loc[mask & Oscars_df["race_ethnicity"].notnull(), "race_ethnicity_gold"] = Oscars_df.loc[mask & Oscars_df["race_ethnicity"].notnull(), "race_ethnicity"]
Oscars_df.loc[mask & Oscars_df["race_ethnicity_gold"].notnull(), "race_ethnicity"] = Oscars_df.loc[mask & Oscars_df["race_ethnicity_gold"].notnull(), "race_ethnicity_gold"]

Oscars_df.loc[mask & Oscars_df["religion"].notnull(), "religion_gold"] = Oscars_df.loc[mask & Oscars_df["religion"].notnull(), "religion"]
Oscars_df.loc[mask & Oscars_df["religion_gold"].notnull(), "religion"] = Oscars_df.loc[mask & Oscars_df["religion_gold"].notnull(), "religion_gold"]

Oscars_df.loc[mask & Oscars_df["birthplace"].notnull(), "birthplace_gold"] = Oscars_df.loc[mask & Oscars_df["birthplace"].notnull(), "birthplace"]
Oscars_df.loc[mask & Oscars_df["birthplace_gold"].notnull(), "birthplace"] = Oscars_df.loc[mask & Oscars_df["birthplace_gold"].notnull(), "birthplace_gold"]

Oscars_df.loc[mask & Oscars_df["sexual_orientation"].notnull(), "sexual_orientation_gold"] = Oscars_df.loc[mask & Oscars_df["sexual_orientation"].notnull(), "sexual_orientation"]
Oscars_df.loc[mask & Oscars_df["sexual_orientation_gold"].notnull(), "sexual_orientation"] = Oscars_df.loc[mask & Oscars_df["sexual_orientation_gold"].notnull(), "sexual_orientation_gold"]

Oscars_df.loc[mask & Oscars_df["year_of_award"].notnull(), "year_of_award_gold"] = Oscars_df.loc[mask & Oscars_df["year_of_award"].notnull(), "year_of_award"]
Oscars_df.loc[mask & Oscars_df["year_of_award_gold"].notnull(), "year_of_award"] = Oscars_df.loc[mask & Oscars_df["year_of_award_gold"].notnull(), "year_of_award_gold"]

# %% [markdown]
# ## La mayoria de los valores existentes se encuentran en las columnas que no son "_gold. Se rellenan las columnas "_gold" con su contraparte.

# %%
Oscars_df['birthplace_gold'] = Oscars_df['birthplace']
Oscars_df['date_of_birth_gold'] = Oscars_df['date_of_birth']
Oscars_df['race_ethnicity_gold'] = Oscars_df['race_ethnicity']
Oscars_df['religion_gold'] = Oscars_df['religion']
Oscars_df['sexual_orientation_gold'] = Oscars_df['sexual_orientation']
Oscars_df['year_of_award_gold'] = Oscars_df['year_of_award']

# %%
Oscars_df['date_of_birth_gold'] = pd.to_datetime(Oscars_df['date_of_birth_gold'], errors='coerce')
Oscars_df['date_of_birth'] = pd.to_datetime(Oscars_df['date_of_birth'], errors='coerce')

# %% [markdown]
# ## Primer Filtro

# %%
Oscars_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 441 entries, 0 to 440
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   _golden                  441 non-null    bool
#  1   _unit_state              441 non-null    object
#  2   _trusted_judgments       441 non-null    int64
#  3   birthplace               441 non-null    object
#  4   date_of_birth            111 non-null    datetime64[ns]
#  5   race_ethnicity           441 non-null    object
#  6   religion                 441 non-null    object
#  7   sexual_orientation       441 non-null    object
#  8   year_of_award            441 non-null    int64
#  9   award                    441 non-null    object
#  10  biourl                   441 non-null    object
#  11  birthplace_gold          441 non-null    object
#  12  date_of_birth_gold       111 non-null    datetime64[ns]
# ...

# %% [markdown]
# ## Scrapping de fechas de nacimiento para aquellos que faltan los datos

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

cols = ["date_of_birth", "date_of_birth_gold", "biourl", "person"]

for index, row in Oscars_df[Oscars_df[cols].isnull().any(axis=1)][cols].iterrows():
    url = row['biourl']
    person_name = row['person']
    
    response = requests.get(url)
    
    if response.status_code == 200:
        soup = BeautifulSoup(response.content, "html.parser")
        paragraphs = soup.find_all("p")
        
        for paragraph in paragraphs:
            if "Born:" in paragraph.get_text():
                birth_info = paragraph.get_text().split("Born:")[1].split("Birthplace:")[0].strip()
                birth_date = birth_info.split(" ")[0]
                
                Oscars_df.loc[Oscars_df['person'] == person_name, ['date_of_birth_gold', 'date_of_birth']] = birth_date, birth_date
                break
    else:
        print("No se pudo acceder a la página:", url)

# %% [markdown]
# ## Segundo filtro

# %%
Oscars_df.info()

# %%
Oscars_df = pd.read_csv(r"C:\Users\Usuario\OneDrive - udd.cl\Datos adjuntos\Bootcamp ciencia de datos\Modulo 7\Proyecto_7_Organizacion_Presentación_Esteban_Freudenberg_UDD\Github_Proyecto_7\Proyectos-Pregrado\Data_used\processed\Scrapped.csv")

# %%
Oscars_df['date_of_birth_gold'] = pd.to_datetime(Oscars_df['date_of_birth_gold'], errors='coerce')
Oscars_df['date_of_birth'] = pd.to_datetime(Oscars_df['date_of_birth'], errors='coerce')

# %%
print((Oscars_df["sexual_orientation"] == "Na").sum())

# %% [markdown]
# ## Decido revisar cual es el año de nacimiento y la orientacion sexual mas comun para decidir con que valor imputar.
# #### No existen registro sobre la orientacion de estas personas en la web.

# %%
print(Oscars_df["sexual_orientation"].value_counts())
print(Oscars_df[Oscars_df["sexual_orientation"] == "Na"]["date_of_birth"])

# %%
Oscars_df.loc[Oscars_df['sexual_orientation'] == 'Na', 'sexual_orientation'] = 'Straight'

# %%
print((Oscars_df["religion"] == "Na").sum())

# %% [markdown]
# ## El 50% de los valores de religion son nulos, por lo que decido eliminar la columna.

# %%
Oscars_df.drop(["religion","religion_gold"], inplace=True,axis=1)

# %%
print((Oscars_df["birthplace"] == "Na").sum())

# %%
Oscars_df[Oscars_df["birthplace"] == "Na"]

# %%
rows_with_nat = Oscars_df[Oscars_df['date_of_birth'].isna()]
print(rows_with_nat)

# %% [markdown]
# ## Estos son los valores que faltan de "birthplace" y "date_of_birth":
#
# ### christoph waltz   / Vienna, Austria  / 4-Oct-1956

# %%
Oscars_df.loc[Oscars_df['person'] == 'Christoph_Waltz', ['date_of_birth_gold', 'date_of_birth']] = '4-Oct-1956'
Oscars_df.loc[Oscars_df['person'] == 'Christoph_Waltz', ['birthplace', 'birthplace_gold']] = 'Vienna_Austria'

# %%
Oscar_limpio = Oscars_df

# %%
Oscar_limpio.to_csv("Oscars_Limpio.csv",index=False)

# %%
Oscars_para_graficos = Oscar_limpio[["birthplace","date_of_birth","race_ethnicity","sexual_orientation","year_of_award","award","movie","person"]]

# %%
Oscars_para_graficos.to_csv("Oscars_para_graficos.csv",index=False)

# %%
Oscars_para_model = Oscar_limpio.drop(["movie","person","biourl","_golden","_unit_state","_trusted_judgments","birthplace_gold","date_of_birth_gold","race_ethnicity_gold","sexual_orientation_gold","year_of_award_gold"],axis=1)

# %%
Oscars_gold = Oscar_limpio[["_golden","_unit_state","birthplace_gold","date_of_birth_gold","race_ethnicity_gold","sexual_orientation_gold","year_of_award_gold"]]

# %%
Oscars_gold.to_csv("Oscars_gold.csv",index=False)

# %%
Oscars_para_model.to_csv('Oscars_para_model.csv', index=False)

# %%
Oscar_limpio.head()

# %% [markdown]
# ## Creacion de coorneadas para graficar mapa y visualizar ubicacion de nacimiento de cada uno de los premiados

# %%
coordinates_dict = {
    'Port_Talbot_Wales': (51.5912, -3.7800),
    'East_Harlem_New_York_City': (40.7947, -73.9422),
    'Concord_Ca': (37.9779, -122.0311),
    'Long_Beach_Ca': (33.7701, -118.1937),
    'Toowoomba_Queensland_Australia': (-27.5610, 151.9530),
    'Misericordia_Arezzo_Tuscany_Italy': (43.4632, 11.8795),
    'South_Orange_Nj': (40.7492, -74.2611),
    'Burbank_Ca': (34.1808, -118.3089),
    'Terrell_Tx': (32.7357, -96.2753),
    'Fairport_Ny': (43.1001, -77.4179),
    'Longview_Tx': (32.5007, -94.7405),
    'Grayshott_Hampshire_England': (51.1152, -0.7457),
    'RueilMalmaison_HautsDeSeine_France': (48.8760, 2.1820),
    'Uvalde_Tx': (29.2097, -99.7861),
    'Swampscott_Ma': (42.4709, -70.9196),
    'Elizabeth_Nj': (40.6631, -74.2107),
    'Walters_Ok': (34.3626, -98.3052),
    'Savannah_Ga': (32.0836, -81.0998),
    'Dublin_Ireland': (53.3498, -6.2603),
    'North_Sydney_Nova_Scotia_Canada': (46.2487, -60.2519),
    'Vale_of_Glamorgan_Wales': (51.4274, -3.2694),
    'Toronto_Ontario_Canada': (43.6511, -79.3830),
    'Lima_Oh': (40.7421, -84.1052),
    'St_Petersburg_Russia': (59.9343, 30.3351),
    'Chihuahua_Mexico': (28.6353, -106.0889),
    'Hoboken_Nj': (40.7434, -74.0324),
    'Hunt_City_Il': (39.6797, -88.5289),
    'Marian_Glas_Anglesey_Wales': (53.3554, -4.2445),
    'Norwood_Oh': (39.1542, -84.4513),
    'Hartford_Ct': (41.7658, -72.6734),
    'Macon_Ga': (32.8407, -83.6324),
    'Bronx_Ny': (40.8448, -73.8648),
    'Malden_Ma': (42.4251, -71.0662),
    'St_Cloud_Mn': (45.5579, -94.1632),
    'Felixstowe_Suffolk_England': (51.9634, 1.3512),
    'Shidler_Ok': (36.8576, -96.6670),
    'Cleveland_Oh': (41.4993, -81.6944),
    'Bucharest_Romania': (44.4268, 26.1025),
    'Astoria_Ny': (40.7644, -73.9235),
    'Malibu_Ca': (34.0259, -118.7798),
    'Samrong_Young_Cambodia': (11.5350, 104.9247),
    'Kenosha_Wi': (42.5847, -87.8212),
    'Bermondsey_England': (51.4975, -0.0800),
    'Edinburgh_Scotland': (55.9533, -3.1883),
    'St_Louis_Mo': (38.6270, -90.1994),
    'Newark_Nj': (40.7357, -74.1724),
    'Lattimer_Mines_Pa': (40.9832, -75.9666),
    'San_Saba_Tx': (31.1965, -98.7170),
    'Laurel_Ne': (42.3947, -97.0991),
    'Lincoln_Lincolnshire_England': (53.2307, -0.5407),
    'West_Covina_Ca': (34.0686, -117.9389),
    'Memphis_Tn': (35.1495, -90.0490),
    'Lexington_Ky': (38.0406, -84.5037),
    'Las_Palmas_De_Gran_Canaria_Canary_Islands': (28.1248, -15.4340),
    'Perth_Australia': (-31.9505, 115.8605),
    'Haverfordwest_Pembrokeshire_Wales': (51.8020, -4.9710),
    'Bossier_City_La': (32.5150, -93.7321),
    'Montreal_Quebec_Canada': (45.5017, -73.5673),
    'Cobourg_Ontario_Canada': (43.9598, -78.1652),
    'Lowell_Ma': (42.6334, -71.3162),
    'Dusseldorf_Germany': (51.2277, 6.7735),
    'Darjeeling_India': (27.0478, 88.2636),
    'Independence_Mo': (39.0911, -94.4155),
    'Tulsa_Ok': (36.1540, -95.9928),
    'Stockholm_Sweden': (59.3293, 18.0686),
    'San_Antonio_Tx': (29.4241, -98.4936),
    'St_Joseph_Mo': (39.7675, -94.8467),
    'Brussels_Belgium': (50.8503, 4.3517),
    'Rome_Italy': (41.9028, 12.4964),
    'Thomasville_Ga': (30.8368, -83.9787),
    'Wiesbaden_Germany': (50.0782, 8.2398),
    'Pozzuoli_Italy': (40.8223, 14.1097),
    'Packard_Ky': (37.6889, -83.3037),
    'WaltononThames_Surrey_England': (51.3854, -0.4162),
    'Chabua_Assam_India': (27.4833, 95.1833),
    'Ilford_Essex_England': (51.5560, 0.0781),
    'Birkenhead_Cheshire_England': (53.3880, -3.0326),
    'Birmingham_Al': (33.5207, -86.8025),
    'Bascom_Fl': (30.8383, -85.1047),
    'Quitman_Tx': (32.7966, -95.4435),
    'Summit_Nj': (40.7159, -74.3646),
    'Kirksville_Mo': (40.1948, -92.5833),
    'Morton_Grove_Il': (42.0406, -87.7825),
    'El_Centro_Ca': (32.7920, -115.5631),
    'Conyers_Ga': (33.6676, -84.0177),
    'Cloquet_Mn': (46.7219, -92.4618),
    'Queens_Ny': (40.7282, -73.7949),
    'Culver_City_Ca': (34.0219, -118.3965),
    'Lincoln_Ne': (40.8136, -96.7026),
    'Smyrna_Ga': (33.8834, -84.5144),
    'Honolulu_Hi': (21.3069, -157.8583),
    'Benoni_South_Africa': (-26.1885, 28.3200),
    'New_Orleans_La': (29.9511, -90.0715),
    'Chiswick_London_England': (51.4892, -0.2610),
    'Reading_England': (51.4543, -0.9781),
    'Arlington_Va': (38.8816, -77.0910),
    'Jerusalem_Israel': (31.7683, 35.2137),
    'Louisville_Ky': (38.2527, -85.7585),
    'Melbourne_Victoria_Australia': (-37.8136, 144.9631),
    'Litchfield_Mn': (45.1276, -94.5265),
    'Wichita_Ks': (37.6872, -97.3301),
    'Palmyra_Mo': (39.7947, -91.5225),
    'Quincy_Il': (39.9356, -91.4099),
    'Athens_Greece': (37.9838, 23.7275),
    'Michigan_City_In': (41.7075, -86.8950),
    'Joliet_Il': (41.5250, -88.0817),
    'Newtonville_Ma': (42.3523, -71.2071),
    'Denison_Ia': (42.0256, -95.3530),
    'Otaro_Hokkaido_Japan': (43.0621, 141.3544),
    'Bramhall_Cheshire_England': (53.3600, -2.1580),
    'Charleroi_Pa': (40.1726, -79.9940),
    'Humacao_Puerto_Rico': (18.1546, -65.8278),
    'Elmhurst_Ny': (40.7376, -73.8785),
    'Hastings_Ne': (40.5865, -98.3912),
    'Marblehead_Ma': (42.5001, -70.8578),
    'Quincy_Ma': (42.2529, -71.0023),
    'Silver_Spring_Md': (39.0046, -77.0369),
    'Des_Moines_Ia': (41.5910, -93.6037),
    'Old_Westbury_Ny': (40.7759, -73.5931),
    'Newport_Ar': (35.6048, -91.2826),
    'Troy_Ny': (42.7284, -73.6918),
    'Morristown_Nj': (40.7968, -74.4815),
    'Wareham_Ma': (41.7598, -70.7222),
    'Winnipeg_Manitoba_Canada': (49.8951, -97.1384),
    'Tenafly_Nj': (40.9254, -73.9625),
    'Athens_Ga': (33.9519, -83.3576),
    'York_North_Yorkshire_England': (53.9591, -1.0815),
    'Catskill_Mountains_Ny': (42.1957, -74.1332),
    'Mumbles_Wales': (51.5680, -3.9763),
    'Katy_Tx': (29.7858, -95.8244),
    'Madrid_Spain': (40.4168, -3.7038),
    'Woodlawn_Md': (39.3051, -76.7720),
    'Montgomery_Al': (32.3668, -86.3006),
    'Mexico_City_Mexico': (19.4326, -99.1332)
}

Coordenadas_1 = pd.DataFrame(list(coordinates_dict.items()), columns=['Location', 'Coordinates'])
Coordenadas_1.head()

import pandas as pd

# Definir los datos
data = {
    'Location': [
        'Chisinau_Moldova', 'Glasgow_Scotland', 'Chicago_Il', 'Salt_Lake_City_Ut',
        'Bisacquino_Sicily_Italy', 'Cape_Elizabeth_Me', 'Los_Angeles_Ca',
        'Pasadena_Ca', 'Mulhouse_HautRhin_Alsace_France', 'Budapest_Hungary',
        'New_York_City', 'Sucha_Galicia_Austria', 'Istanbul_Turkey', 'Nevada_Mo',
        'WilkesBarre_Pa', 'Oakland_Ca', 'Vienna_Austria', 'Lawrence_Ks',
        'Croydon_Surrey_England', 'Winchester_In', 'Shipley_Yorkshire_England',
        'Berlin_Germany', 'St_Louis_Park_Mn', 'London_England', 'Tokyo_Japan',
        'Minneapolis_Mn', 'Detroit_Mi', 'CÌÁslav_Czechoslovakia', 'Oak_Park_Il',
        'Brooklyn_Ny', 'Waxahachie_Tx', 'Santa_Monica_Ca', 'Richmond_Va',
        'Cambridge_England', 'North_Bergen_Nj', 'Lafayette_In',
        'Parma_EmiliaRomagna_Italy', 'Baltimore_Md', 'Lynwood_Ca', 'Baldwin_Ny',
        'San_Francisco_Ca', 'Cincinnati_Oh', 'Peekskill_Ny',
        'Ryde_Isle_of_Wight_England', 'Kapuskasing_Ontario_Canada',
        'Reading_Berkshire_England', 'Atlanta_Ga', 'Duncan_Ok', 'Paris_France',
        'Wellington_New_Zealand', 'Pingtung_Taiwan', 'Flushing_Ny',
        'Manchester_England', 'San_Carlos_Ca', 'Rorschach_Switzerland',
        'Columbus_Oh', 'Philadelphia_Pa', 'Kansas_City_Mo',
        'Victoria_Hotel_Scarborough_Yorkshire_England', 'Cadiz_Oh',
        'Tunbridge_Wells_Kent_England', 'Lviv_Ukraine', 'Milwaukee_Wi',
        'Withington_Manchester_England', 'Indiana_Pa', 'Helena_Mt', 'Manhattan_Ny',
        'Tacoma_Wa', 'Neath_Wales', 'Racine_Wi', 'Richmond_Surrey_England',
        'Dorking_Surrey_England', 'Santurce_Puerto_Rico', 'Ofallon_Il', 'Omaha_Ne',
        'Hamden_Ct', 'Vladivostok_Russia', 'Evanston_Il', 'La_Jolla_Ca', 'Miami_Fl',
        'Huyton_Lancashire_England', 'Hurstpierpoint_West_Sussex_England',
        'Westhampton_Ny', 'Winterset_Ia', 'Wise_Va', 'San_Bernardino_Ca', 'Newton_Ma',
        'Mount_Vernon_Ny', 'South_Kensington_London_England', 'Yonkers_Ny',
        'Grand_Island_Ne', 'Scarborough_Yorkshire_England', 'San_Diego_Ca',
        'Pittsburgh_Pa', 'Washington_Dc', 'Shaker_Heights_Oh', 'New_Brunswick_Nj',
        'Cowes_Isle_of_Wight_England'
    ],
    'Coordinates': [
        [47.010452, 28.86381], [55.864237, -4.251806], [41.878113, -87.629799], [40.760779, -111.891047],
        [37.795041, 13.258076], [43.563484, -70.22682], [34.052235, -118.243683], [34.147785, -118.144515],
        [47.750839, 7.335888], [47.497913, 19.040236], [40.712776, -74.005974], [49.634785, 22.67423],
        [41.008237, 28.97836], [37.839333, -94.354869], [41.245914, -75.881307], [37.804363, -122.271111],
        [48.208354, 16.372504], [38.971669, -95.23525], [51.376165, -0.098234], [40.174554, -85.488863],
        [53.833333, -1.783333], [52.520008, 13.404954], [44.948333, -93.348611], [51.507351, -0.127758],
        [35.682839, 139.759455], [44.977753, -93.265011], [42.331429, -83.045753], [49.903761, 15.377264],
        [41.885031, -87.784502], [40.650002, -73.949997], [32.386433, -96.848331], [34.019394, -118.491191],
        [37.540726, -77.43605], [52.205276, 0.119167], [40.804283, -74.012083], [40.416702, -86.875286],
        [44.801485, 10.327903], [39.290386, -76.61219], [33.930293, -118.21146], [40.652954, -73.607159],
        [37.774929, -122.419418], [39.103119, -84.512016], [41.290387, -73.920857], [50.730548, -1.160299],
        [49.416668, -82.433334], [51.454514, -0.973168], [33.748997, -84.387985], [34.502303, -97.957813],
        [48.856613, 2.352222], [-41.28664, 174.77557], [22.681614, 120.481592], [40.764462, -73.831693],
        [53.480759, -2.242631], [37.504311, -122.261796], [47.477522, 9.482359], [39.961178, -82.998795],
        [39.952583, -75.165222], [39.099731, -94.578568], [54.283333, -0.4], [40.273703, -81.865104],
        [51.132377, 0.263695], [49.839684, 24.029717], [43.038902, -87.906471], [53.441143, -2.257355],
        [40.621212, -79.15295], [46.58976, -112.03912], [40.78343, -73.96625], [47.252877, -122.44429],
        [51.661385, -3.804017], [42.726131, -87.782852], [51.461311, -0.303742], [51.231049, -0.324404],
        [18.439216, -66.061967], [38.592323, -89.910989], [41.256535, -95.934502], [41.383878, -72.902606],
        [43.115536, 131.885485], [42.044738, -87.693046], [32.832811, -117.271272], [25.76168, -80.19179],
        [53.408371, -2.839239], [50.93824, -0.235722], [40.830132, -72.689713], [41.330863, -94.013631],
        [36.975942, -82.575234], [34.10834, -117.289765], [42.33698, -71.209221], [40.9126, -73.8371],
        [51.494067, -0.174604], [40.93121, -73.89875], [40.926395, -98.342013], [54.282879, -0.401187],
        [32.715736, -117.161087], [40.440624, -79.995888], [38.89511, -77.03637], [41.473942, -81.53767],
        [40.486217, -74.451817], [50.762069, -1.298]
    ]
}

# Crear el DataFrame
Coordenadas_2 = pd.DataFrame(data)

# Mostrar el DataFrame
print(Coordenadas_2)

Coordenadas_1['Coordinates'] = Coordenadas_1['Coordinates'].apply(lambda x: list(x))
Coordenadas_combinadas = pd.concat([Coordenadas_1, Coordenadas_2], ignore_index=True)


Oscar_limpio = pd.read_csv(r"C:\Users\Usuario\OneDrive - udd.cl\Datos adjuntos\Bootcamp ciencia de datos\Modulo 7\Proyecto_7_Organizacion_Presentación_Esteban_Freudenberg_UDD\Proyecto_7_Esteban\processed\Oscars_Limpio.csv")
Oscar_limpio['Coordinates'] = Oscar_limpio['birthplace'].map(Coordenadas_combinadas.set_index('Location')['Coordinates'])

# %%
import pandas as pd

# Definir los datos
data = {
    'Location': [
        'Chisinau_Moldova', 'Glasgow_Scotland', 'Chicago_Il', 'Salt_Lake_City_Ut',
        'Bisacquino_Sicily_Italy', 'Cape_Elizabeth_Me', 'Los_Angeles_Ca',
        'Pasadena_Ca', 'Mulhouse_HautRhin_Alsace_France', 'Budapest_Hungary',
        'New_York_City', 'Sucha_Galicia_Austria', 'Istanbul_Turkey', 'Nevada_Mo',
        'WilkesBarre_Pa', 'Oakland_Ca', 'Vienna_Austria', 'Lawrence_Ks',
        'Croydon_Surrey_England', 'Winchester_In', 'Shipley_Yorkshire_England',
        'Berlin_Germany', 'St_Louis_Park_Mn', 'London_England', 'Tokyo_Japan',
        'Minneapolis_Mn', 'Detroit_Mi', 'CÌÁslav_Czechoslovakia', 'Oak_Park_Il',
        'Brooklyn_Ny', 'Waxahachie_Tx', 'Santa_Monica_Ca', 'Richmond_Va',
        'Cambridge_England', 'North_Bergen_Nj', 'Lafayette_In',
        'Parma_EmiliaRomagna_Italy', 'Baltimore_Md', 'Lynwood_Ca', 'Baldwin_Ny',
        'San_Francisco_Ca', 'Cincinnati_Oh', 'Peekskill_Ny',
        'Ryde_Isle_of_Wight_England', 'Kapuskasing_Ontario_Canada',
        'Reading_Berkshire_England', 'Atlanta_Ga', 'Duncan_Ok', 'Paris_France',
        'Wellington_New_Zealand', 'Pingtung_Taiwan', 'Flushing_Ny',
        'Manchester_England', 'San_Carlos_Ca', 'Rorschach_Switzerland',
        'Columbus_Oh', 'Philadelphia_Pa', 'Kansas_City_Mo',
        'Victoria_Hotel_Scarborough_Yorkshire_England', 'Cadiz_Oh',
        'Tunbridge_Wells_Kent_England', 'Lviv_Ukraine', 'Milwaukee_Wi',
        'Withington_Manchester_England', 'Indiana_Pa', 'Helena_Mt', 'Manhattan_Ny',
        'Tacoma_Wa', 'Neath_Wales', 'Racine_Wi', 'Richmond_Surrey_England',
        'Dorking_Surrey_England', 'Santurce_Puerto_Rico', 'Ofallon_Il', 'Omaha_Ne',
        'Hamden_Ct', 'Vladivostok_Russia', 'Evanston_Il', 'La_Jolla_Ca', 'Miami_Fl',
        'Huyton_Lancashire_England', 'Hurstpierpoint_West_Sussex_England',
        'Westhampton_Ny', 'Winterset_Ia', 'Wise_Va', 'San_Bernardino_Ca', 'Newton_Ma',
        'Mount_Vernon_Ny', 'South_Kensington_London_England', 'Yonkers_Ny',
        'Grand_Island_Ne', 'Scarborough_Yorkshire_England', 'San_Diego_Ca',
        'Pittsburgh_Pa', 'Washington_Dc', 'Shaker_Heights_Oh', 'New_Brunswick_Nj',
        'Cowes_Isle_of_Wight_England'
    ],
    'Coordinates': [
        [47.010452, 28.86381], [55.864237, -4.251806], [41.878113, -87.629799], [40.760779, -111.891047],
        [37.795041, 13.258076], [43.563484, -70.22682], [34.052235, -118.243683], [34.147785, -118.144515],
        [47.750839, 7.335888], [47.497913, 19.040236], [40.712776, -74.005974], [49.634785, 22.67423],
        [41.008237, 28.97836], [37.839333, -94.354869], [41.245914, -75.881307], [37.804363, -122.271111],
        [48.208354, 16.372504], [38.971669, -95.23525], [51.376165, -0.098234], [40.174554, -85.488863],
        [53.833333, -1.783333], [52.520008, 13.404954], [44.948333, -93.348611], [51.507351, -0.127758],
        [35.682839, 139.759455], [44.977753, -93.265011], [42.331429, -83.045753], [49.903761, 15.377264],
        [41.885031, -87.784502], [40.650002, -73.949997], [32.386433, -96.848331], [34.019394, -118.491191],
        [37.540726, -77.43605], [52.205276, 0.119167], [40.804283, -74.012083], [40.416702, -86.875286],
        [44.801485, 10.327903], [39.290386, -76.61219], [33.930293, -118.21146], [40.652954, -73.607159],
        [37.774929, -122.419418], [39.103119, -84.512016], [41.290387, -73.920857], [50.730548, -1.160299],
        [49.416668, -82.433334], [51.454514, -0.973168], [33.748997, -84.387985], [34.502303, -97.957813],
        [48.856613, 2.352222], [-41.28664, 174.77557], [22.681614, 120.481592], [40.764462, -73.831693],
        [53.480759, -2.242631], [37.504311, -122.261796], [47.477522, 9.482359], [39.961178, -82.998795],
        [39.952583, -75.165222], [39.099731, -94.578568], [54.283333, -0.4], [40.273703, -81.865104],
        [51.132377, 0.263695], [49.839684, 24.029717], [43.038902, -87.906471], [53.441143, -2.257355],
        [40.621212, -79.15295], [46.58976, -112.03912], [40.78343, -73.96625], [47.252877, -122.44429],
        [51.661385, -3.804017], [42.726131, -87.782852], [51.461311, -0.303742], [51.231049, -0.324404],
        [18.439216, -66.061967], [38.592323, -89.910989], [41.256535, -95.934502], [41.383878, -72.902606],
        [43.115536, 131.885485], [42.044738, -87.693046], [32.832811, -117.271272], [25.76168, -80.19179],
        [53.408371, -2.839239], [50.93824, -0.235722], [40.830132, -72.689713], [41.330863, -94.013631],
        [36.975942, -82.575234], [34.10834, -117.289765], [42.33698, -71.209221], [40.9126, -73.8371],
        [51.494067, -0.174604], [40.93121, -73.89875], [40.926395, -98.342013], [54.282879, -0.401187],
        [32.715736, -117.161087], [40.440624, -79.995888], [38.89511, -77.03637], [41.473942, -81.53767],
        [40.486217, -74.451817], [50.762069, -1.298]
    ]
}

# Crear el DataFrame
Coordenadas_2 = pd.DataFrame(data)

# Mostrar el DataFrame
print(Coordenadas_2)

# %%
Coordenadas_1['Coordinates'] = Coordenadas_1['Coordinates'].apply(lambda x: list(x))
Coordenadas_combinadas = pd.concat([Coordenadas_1, Coordenadas_2], ignore_index=True)

# %%
Oscars_para_graficos['Coordinates'] = Oscars_para_graficos['birthplace'].map(Coordenadas_combinadas.set_index('Location')['Coordinates'])

# %%
Oscars_para_graficos.to_csv("Oscars_con_coordenadas.csv",index=False)

# %%
Oscars_con_coordenadas.info()

# %%
import folium
import pandas as pd

# Cargar el DataFrame con los datos
# Asumiendo que 'Oscars_para_graficos' ya está cargado
# df = pd.read_csv('ruta/al/archivo.csv')  # Por ejemplo, si los datos están en un archivo CSV

# Crear un mapa centrado en una ubicación inicial (por ejemplo, Los Ángeles)
mapa = folium.Map(location=[34.0928092, -118.3286614], zoom_start=4)

# Iterar sobre cada fila del DataFrame para añadir marcadores al mapa
for index, row in Oscars_con_coordenadas.iterrows():
    # Obtener las coordenadas de la columna 'Coordinates'
    coords = row['Coordinates']
    lat, lon = coords[0], coords[1]

    popup_text = f"Lugar nacimiento: {row['birthplace']}<br>Premiado: {row['person']}<br>Año premiación: {row['year_of_award']}"
    folium.Marker([lat, lon], 
                  popup=folium.Popup(popup_text, max_width=300)).add_to(mapa)
# Guardar el mapa como un archivo HTML
mapa.save('mapa_premios_oscar.html')

# Mostrar el mapa en Jupyter Notebook (si estás usando Jupyter)
mapa

# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
import pandas as pd
import plotly.express as px


Oscars_con_coordenadas[['lat', 'lon']] = pd.DataFrame(Oscars_con_coordenadas['Coordinates'].tolist(), index=Oscars_para_graficos.index)

# Crear la figura del mapa
fig = px.scatter_mapbox(Oscars_con_coordenadas, lat='lat', lon='lon',
                        hover_name='person', hover_data={'lat': False, 'lon': False, 'birthplace': True, 'year_of_award': True},
                        zoom=4, height=600)

# Configurar el mapa con el estilo de Mapbox
fig.update_layout(mapbox_style="open-street-map")
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})

# Crear la aplicación Dash
app = dash.Dash(__name__)

app.layout = html.Div([
    html.H1("Mapa de Premios Oscar"),
    dcc.Graph(figure=fig)
])

# Ejecutar la aplicación
if __name__ == '__main__':
    app.run_server(debug=True)
